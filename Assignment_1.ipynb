# %% [markdown]
# ##### Information-theretic analysis of language models (Fall 2022/3)
#
#
# # Home Assignment 1
#
# #### Topics:
# 1. $N$-gram language models
# 2. Entropy (definition)
#
#
# #### Due: 24/11/2022 by class time
#
# #### Instructions:
# - Write your name, Student ID, and date in the cell below.
# - Submit a copy of this notebook with code filled in the relevant places as the solution of coding excercises.
# - For theoretic excercises, you can either write your solution in the notebook using $\LaTeX$ or submit additional notes.
#
# <hr>
# <hr>

# %% [markdown]
# **Name**: Elad Prager
#
# **Student ID**: 200865780
#
# **Date**: 24/11/22
#
# $
# \newcommand{\Id}{{\mathbf{I}}}
# \newcommand{\SSE}{\mathsf{SSE}}
# \newcommand{\SSR}{\mathsf{SSR}}
# \newcommand{\MSE}{\mathsf{MSE}}
# \newcommand{\simiid}{\overset{iid}{\sim}}
# \newcommand{\ex}{\mathbb E}
# \newcommand{\var}{\mathrm{Var}}
# \newcommand{\Cov}[2]{{\mathrm{Cov}  \left(#1, #2 \right)}}
# \newcommand{\one}[1]{\mathbf 1 {\left\{#1\right\}}}
# \newcommand{\SE}[1]{\mathrm{SE} \left[#1\right]}
# \newcommand{\reals}{\mathbb R}
# \newcommand{\Ncal}{\mathcal N}
# \newcommand{\abs}[1]{\ensuremath{\left\vert#1\right\vert}}
# \newcommand{\rank}{\operatorname{rank}}
# \newcommand{\tr}{\operatorname{Tr}}
# \newcommand{\diag}{\operatorname{diag}}
# \newcommand{\sign}{\operatorname{sign}}
# \newcommand{\Ycal}{\mathcal Y}
# \newcommand{\Xcal}{\mathcal X}
# \newcommand{\Zcal}{\mathcal Z}
# \newcommand{\Wcal}{\mathcal W}
# $

# %% [markdown]
# ### 1. $N$-gram model of *pride and prejudice*
# You can use code from the jupyter notebook presented in class. The notebook is available on Moodle.
# The data is the content of the file `pride and prejudice.txt` available on Moodle. This file is taken from https://www.gutenberg.org/files/1342/1342-0.txt with metadata and preface removed.
#
#
# 1. Build an $N$-gram model using all the text of `pride and prejudice.txt` for $N=3$.
#     - How many tokens are in your vocabulary?
# 2. Sample and print 10 sentences from this model.
# 3. Evaluate perplexity; use cross-validation:
#     - Split the data into roughly 10 equal parts
#     - Repeat for all $i=1,\ldots,10$:
#         - At step $i$, set aside part $i$ and build a model using the remaining $9$ parts.
#         - Evalaute the log perplexity of the model based on the set aside part. You may skip sentences containing unseen words (remove those sentences from the average)
#     - Report the averaged log perplexity over all parts
# 4. Say that you evaluate the log preplexity of the model in (1) under a new text created by sampling from the model as in (2). Would that log perplexity be smaller or larger than the one you found in (3)? Why?
#     - Verify your claim by estimating the perplexity of the model under at least 1,000 sentences you generated by sampling from the model you created in (1).

# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import re

from sklearn.model_selection import KFold
from matplotlib import pyplot as plt
from tqdm import tqdm
from nltk import ngrams

# %% [markdown]
# ## read dataset

# %%
with open("../content/pride and prejudice.txt", 'rt') as f:
    text = f.read()
print("Number of tokens (without preprocessing) = ", len(text.split()))
# Out:
# Number of tokens (without preprocessing) =  124467

# %% [markdown]
# **Number of tokens (without preprocessing) =  124467**

# %%
df = pd.read_csv("/content/pride and prejudice.txt", sep='delimiter')
df.columns = ['transcript']
print(df.describe())
print(df.head())
# Out:
#         transcript
# count        12069
# unique       12040
# top     Elizabeth.
# freq             5
#                                           transcript
# 0  It is a truth universally acknowledged, that a...
# 1  possession of a good fortune, must be in want ...
# 2  However little known the feelings or views of ...
# 3  on his first entering a neighbourhood, this tr...
# 4  fixed in the minds of the surrounding families...
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %% [markdown]
# ## build 3-gram model

# %%
TOKEN_PATTERN = r"(?u)\b[a-zA-Z]+\b|\</?s\>"
SENT_START_TOKEN = '<s>'
SENT_END_TOKEN = '</s>'

def split_to_sentences(text: str, sep=r'\.|\n') -> str:
    return re.split(sep, text)

def is_sublist(list_a: list, list_b: list)-> bool:
    return str(list_a).strip('[').strip(']') in str(list_b)

def ng_tokenize(text: str, ng: int) -> list:
    tokens = re.findall(TOKEN_PATTERN, text.lower())
    ngz = ngrams(tokens, ng,
                 pad_left=True, pad_right=True,
                 left_pad_symbol=SENT_START_TOKEN,
                 right_pad_symbol=SENT_END_TOKEN)
    return list(ngz)

def clean_text(text: str) -> str: 
    text = text.lower()
    text = re.sub(r"<br ?/>", " ", text)  # replace '<br />' with ' '
    text = re.sub(r"\.\.+", " ", text)  # replace '..' or a longer sequence with ' '
    text = re.sub(r"-", " ", text)

    return text

def build_ngram_model(text: str, ng: int) -> pd.DataFrame:
    """
    1. Clean text
    2. Add sentence begin and end symbols
    3. Extract ngrams
    4. Remove unwanted tokens
    5. Compute frequency of every token
    
    Returns:
      dataframe. Indexes are ngrams. Columns indiacte number of occurances 
      and frequency of occurance
    """
    print("Cleaning text...")
    text = clean_text(text)
    print("Breaking to sentences")
    sentences = split_to_sentences(text)
    print("Extracting tokens...")
    tokens = []
    for sent in tqdm(sentences):
        tokens += ng_tokenize(sent, ng)
    print("Removing unacceptible tokens...")
    tokens = [t for t in tokens if not 
              (('<s>' in t[1:]) or ('</s>' in t[:-1]) or (is_sublist(["<s>", "</s>"], t)))]
    print("Counting tokens...")
    df_ng = pd.DataFrame(pd.DataFrame(tokens).value_counts()).rename(columns = {0 : 'count'})
    print("Computing frequencies...")
    df_ng.loc[:, 'freq'] = df_ng['count'] / df_ng['count'].sum()  # compute frequencies
    return df_ng

# %%
model_1gram = build_ngram_model(" ".join(df.transcript), ng=1)
# Out:
# Cleaning text...
# Breaking to sentences
# Extracting tokens...
# 100%|██████████| 6399/6399 [00:00<00:00, 82415.76it/s]
# Removing unacceptible tokens...
# Counting tokens...
# Computing frequencies...

# %%
print(model_1gram.head(20))
# Out:
#       count      freq
# 0
# the    4511  0.035999
# to     4244  0.033868
# of     3727  0.029742
# and    3650  0.029128
# her    2202  0.017572
# i      2048  0.016343
# a      2006  0.016008
# in     1937  0.015458
# was    1846  0.014731
# she    1691  0.013495
# that   1555  0.012409
# it     1547  0.012345
# not    1448  0.011555
# you    1397  0.011148
# he     1328  0.010598
# his    1257  0.010031
# be     1256  0.010023
# as     1193  0.009520
# had    1172  0.009353
# with   1096  0.008746

# %%
print(f'Number of tokens (after preprocessing) = {len(model_1gram)}')
# Out:
# Number of tokens (after preprocessing) = 6500

# %% [markdown]
# **Number of tokens (after preprocessing) = 6500** (My ngram model clean punctuations and dashes)

# %%
model_3gram = build_ngram_model(" ".join(df.transcript), ng=3)
# Out:
# Cleaning text...
# Breaking to sentences
# Extracting tokens...
# 100%|██████████| 6399/6399 [00:00<00:00, 78386.18it/s]
# Removing unacceptible tokens...
# Counting tokens...
# Computing frequencies...

# %%
k = 15
print(f"{k} most frequent 3grams:")
print(model_3gram.head(k))
# Out:
# 15 most frequent 3grams:
#                         count      freq
# 0       1         2
# <s>     mr        </s>    138  0.001101
#         i         am       91  0.000726
#         mrs       </s>     89  0.000710
#         it        was      83  0.000662
# of      mr        </s>     66  0.000527
# i       am        sure     62  0.000495
# <s>     it        is       60  0.000479
# i       do        not      59  0.000471
# project gutenberg tm       57  0.000455
# as      soon      as       55  0.000439
# she     could     not      50  0.000399
# <s>     i         have     47  0.000375
#         she       was      47  0.000375
# and     mrs       </s>     46  0.000367
#         mr        </s>     42  0.000335

# %% [markdown]
# ## sample sentences

# %%
import warnings

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)


def sample_from_model(ngram_model, prompt=['<s>']):
    
    def sample_from_list(df):
        return df.sample(n=1, weights = df.freq)
    
    w = ''
    state = prompt
    smp = sample_from_list(ngram_model.loc[state])
    state = list(smp.index[0][1:])
    w = list(state)
    while w[-1] != '</s>': 
        df_pool = ngram_model.loc[tuple(state)]
        smp = df_pool.sample(n=1, weights = df_pool.freq)
        state = state[1:] + [smp.index[0]]
        w.append(state[-1])
    return w[:-1] + ['</s>']

# %%
for i in range(10):
  prompt = ['<s>']
  print(" ".join(prompt + sample_from_model(model_3gram, prompt=prompt)))
# Out:
# <s> recovering himself advanced towards the persons who so assiduously courted you </s>
# <s> this part of the mother in law of wickham s a fool s errand again </s>
# <s> i shall not find a very easy distance </s>
# <s> collins </s>
# <s> when she asked the chambermaid whether pemberley were not </s>
# <s> his acquaintance with her in darcy s presence be what pin money what occasion could there be any extenuating circumstances in the habit of brooking disappointment </s>
# <s> he concluded his speech with a solemn bow and though his pride never deserts him but would quit town the following morning </s>
# <s> if the first place he must be greater than at home she had no turn for economy and other amiable qualification </s>
# <s> if his own his aunt lady catherine de bourgh s family is indeed but considering the event must be obeyed and further apology would be spoilt by admitting a fourth </s>
# <s> what shall we punish him for us to day said miss bingley with the creative eye of fancy on my poor sister </s>

# %% [markdown]
# ## Evaluate perplexity

# %%
class State(object):
    def __init__(self, past: list, present: list, future: list):
        self.past = past
        self.present = present
        self.future = future
        
    def step(self):
        self.past += self.present
        if len(self.future) > 0:
            self.present = [self.future.pop(0)]
        else:
            self.present = []
            self.future = []
            
    def print_state(self):
        print("past:", self.past)
        print("present:", self.present)
        print("future:", self.future)

# %%
def token_probability(token : str, model: pd.DataFrame) -> float:
    if len(token) == 0:  
        return 1     # we agree that an empty token has probability 1
    token_idx = tuple(token)
    
    if token_idx in model.index:
        return model.loc[token_idx].freq.sum()  # the sum is to allow marginalization if
                                                # the token is smaller than an n-gram
    # else:
    print(f"Unrecognized Token {token}")
    raise ValueError                

def conditional_probability(token_a: list, token_b: list, model: pd.DataFrame, verbose=False) -> float:   
    pr_b = token_probability(token_b, model)
    pr_ab = token_probability(token_b + token_a, model)
    return pr_ab / pr_b
    
def sentence_probability(sent: str, model: pd.DataFrame,
                         verbose=False, backoff=False) -> float:
    ng = len(model.index[0])  # identify model order

    sent_atoms = sent.split()  
    first_token = sent_atoms[:1] 

    word_stream = State(past=[], present=first_token, future=sent_atoms[1:])

    # update state
    logprob = 0
    while len(word_stream.present) > 0:
        if backoff:
            pr_token = conditional_probability_backoff(word_stream.present,
                                                       word_stream.past[-ng+1:],
                                                       model, verbose=verbose)
        else:
            pr_token = conditional_probability(word_stream.present, word_stream.past[-ng+1:],
                                               model)
        logprob += np.log(pr_token)
        if verbose:
            word_stream.print_state()
            print(f"P(present|past) = {pr_token}")
            print("------------------------------------")
        word_stream.step()

    return np.exp(logprob)

def conditional_probability_backoff(token_a:str, token_b:str, model: pd.DataFrame, verbose=False) -> float:
    joint_token_idx = tuple(token_b + token_a)
        
    if (joint_token_idx not in model.index) and (token_b != []):
        if verbose:
            print(f"Token_a = {token_a}, Backing-off from {token_b} to {token_b[1:]}...")
        
        return conditional_probability_backoff(token_a, token_b[1:], model)
    
    return conditional_probability(token_a, token_b, model)

# %%
def logperplexity(sentence: str, model: pd.DataFrame) -> float:
    N = len(sentence.split())
    prob = sentence_probability(sentence, model, backoff=True)
    return -np.log(prob) / N

# %%
def preprocess_sentence(text: str) -> str:
    return  '<s> ' + " ".join(re.findall(TOKEN_PATTERN, text)).lower() + ' </s>'

def to_sentences(text: str) -> list:
    text = clean_text(text)
    sentences = split_to_sentences(text)
    return [preprocess_sentence(sent) for sent in sentences if len(sent.split()) > 2]

# %% [markdown]
# ## KFold Model

# %%
kf = KFold(n_splits = 10, shuffle = True, random_state = 2)
iterator = iter(kf.split(df))
ls = []
for i in range(10):
  result = next(iterator)
  train = df.iloc[result[0]]
  test =  df.iloc[result[1]]
  train.columns = ['transcript']
  test.columns = ['transcript']

  model_3gram = build_ngram_model(" ".join(train.transcript), ng=3)

  test_sentences = test.transcript.tolist()
  for sent in test_sentences:
    cleaned_text = clean_text(sent)
    cleaned_text = re.sub(r"[^a-z0-9 ]+", " ", cleaned_text)
    try:
      lpp = logperplexity(cleaned_text, model_3gram)
      if lpp > 0:
          ls += [lpp]
    except:
      print("Cound not evaluate perplexity of sent: ", sent)
print(f"Average LPP of bigram model over {len(ls)} samples: {np.mean(ls)}, (std = {np.std(ls)})")
# Out:
# Cleaning text...
# Breaking to sentences
# Extracting tokens...
# 100%|██████████| 5738/5738 [00:00<00:00, 33380.00it/s]
# Removing unacceptible tokens...
# Counting tokens...
# Computing frequencies...
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  The girls stared at their father. Mrs. Bennet said only,
# Unrecognized Token ['stress']
# Cound not evaluate perplexity of sent:  “Do you consider the forms of introduction, and the stress that
# Unrecognized Token ['adjusting']
# Cound not evaluate perplexity of sent:  “While Mary is adjusting her ideas,” he continued, “let us return
# Unrecognized Token ['3']
# Cound not evaluate perplexity of sent:  Chapter 3
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  already had Mrs. Bennet planned the courses that were to do
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Hurst, merely looked the gentleman; but his friend Mr. Darcy soon
# Unrecognized Token ['forbidding']
# Cound not evaluate perplexity of sent:  forbidding, disagreeable countenance, and being unworthy to be
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  and his friend! Mr. Darcy danced only once with Mrs. Hurst and
# Unrecognized Token ['ankle']
# Cound not evaluate perplexity of sent:  ankle in the first dance!”
# Unrecognized Token ['4']
# Cound not evaluate perplexity of sent:  Chapter 4
# Unrecognized Token ['ductility']
# Cound not evaluate perplexity of sent:  Darcy by the easiness, openness, and ductility of his temper,
# Unrecognized Token ['offence']
# Cound not evaluate perplexity of sent:  giving offence.
# Unrecognized Token ['piqued']
# Cound not evaluate perplexity of sent:  “Pride,” observed Mary, who piqued herself upon the solidity of
# Unrecognized Token ['cherish']
# Cound not evaluate perplexity of sent:  there are very few of us who do not cherish a feeling of
# Unrecognized Token ['goodwill']
# Cound not evaluate perplexity of sent:  manners grew on the goodwill of Mrs. Hurst and Miss Bingley; and
# Unrecognized Token ['intolerable']
# Cound not evaluate perplexity of sent:  though the mother was found to be intolerable, and the younger
# Unrecognized Token ['beforehand']
# Cound not evaluate perplexity of sent:  well known to each other, or ever so similar beforehand, it does
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  an object of some interest in the eyes of his friend. Mr. Darcy
# Unrecognized Token ['failure']
# Cound not evaluate perplexity of sent:  Though he had detected with a critical eye more than one failure
# Unrecognized Token ['persevering']
# Cound not evaluate perplexity of sent:  Miss Lucas’s persevering, however, she added, “Very well; if it
# Unrecognized Token ['swell']
# Cound not evaluate perplexity of sent:  mine to swell my song.”
# Unrecognized Token ['nothingness']
# Cound not evaluate perplexity of sent:  the noise; the nothingness, and yet the self-importance of all
# Unrecognized Token ['jumps']
# Cound not evaluate perplexity of sent:  lady’s imagination is very rapid; it jumps from admiration to
# Unrecognized Token ['7']
# Cound not evaluate perplexity of sent:  Chapter 7
# Unrecognized Token ['bare']
# Cound not evaluate perplexity of sent:  conversation for the evening; and however bare of news the
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  They are wanted in the farm, Mr. Bennet, are not they?”
# Unrecognized Token ['prognostics']
# Cound not evaluate perplexity of sent:  cheerful prognostics of a bad day. Her hopes were answered; Jane
# Unrecognized Token ['intruder']
# Cound not evaluate perplexity of sent:  prevented her feeling herself so much an intruder as she believed
# Unrecognized Token ['inches']
# Cound not evaluate perplexity of sent:  “Yes, and her petticoat; I hope you saw her petticoat, six inches
# Unrecognized Token ['asleep']
# Cound not evaluate perplexity of sent:  seeing her asleep, and when it appeared to her rather right than
# Unrecognized Token ['netting']
# Cound not evaluate perplexity of sent:  deserves it no otherwise than by netting a purse or covering a
# Unrecognized Token ['alter']
# Cound not evaluate perplexity of sent:  “But people themselves alter so much, that there is something new
# Unrecognized Token ['shops']
# Cound not evaluate perplexity of sent:  country, for my part, except the shops and public places. The
# Unrecognized Token ['mistook']
# Cound not evaluate perplexity of sent:  her mother. “You quite mistook Mr. Darcy. He only meant that
# Unrecognized Token ['enable']
# Cound not evaluate perplexity of sent:  Nothing but concern for Elizabeth could enable Bingley to keep
# Unrecognized Token ['food']
# Cound not evaluate perplexity of sent:  “I have been used to consider poetry as the _food_ of love,” said
# Unrecognized Token ['tremble']
# Cound not evaluate perplexity of sent:  Elizabeth tremble lest her mother should be exposing herself
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  you always write such charming long letters to her, Mr. Darcy?”
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy smiled; but Elizabeth thought she could perceive that
# Unrecognized Token ['seize']
# Cound not evaluate perplexity of sent:  “Do not you feel a great inclination, Miss Bennet, to seize such
# Unrecognized Token ['cheating']
# Cound not evaluate perplexity of sent:  cheating a person of their premeditated contempt. I have,
# Unrecognized Token ['admitting']
# Cound not evaluate perplexity of sent:  admitting a fourth. Good-bye.”
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Bingley succeeded no less in the real object of her civility; Mr.
# Unrecognized Token ['tease']
# Cound not evaluate perplexity of sent:  Elizabeth. “We can all plague and punish one another. Tease
# Unrecognized Token ['tease']
# Cound not evaluate perplexity of sent:  has not yet taught me _that_. Tease calmness of manner and
# Unrecognized Token ['hinted']
# Cound not evaluate perplexity of sent:  hinted that Colonel Forster was going to be married.
# Unrecognized Token ['iniquitous']
# Cound not evaluate perplexity of sent:  “It certainly is a most iniquitous affair,” said Mr. Bennet, “and
# Unrecognized Token ['rectory']
# Cound not evaluate perplexity of sent:  the valuable rectory of this parish, where it shall be my earnest
# Unrecognized Token ['hearers']
# Cound not evaluate perplexity of sent:  This gallantry was not much to the taste of some of his hearers;
# Unrecognized Token ['cook']
# Cound not evaluate perplexity of sent:  cook, and that her daughters had nothing to do in the kitchen. He
# Unrecognized Token ['pool']
# Cound not evaluate perplexity of sent:  before, to make up her pool of quadrille in the evening. Lady
# Unrecognized Token ['superintended']
# Cound not evaluate perplexity of sent:  the lady who superintended her education, and who still resides
# Unrecognized Token ['amazes']
# Cound not evaluate perplexity of sent:  benefit. It amazes me, I confess; for, certainly, there can be
# Unrecognized Token ['seniority']
# Cound not evaluate perplexity of sent:  what was due to seniority; and for the first evening _she_ was
# Unrecognized Token ['te']
# Cound not evaluate perplexity of sent:  alteration; for in a quarter of an hour’s _tête-à-tête_ with Mrs.
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet treasured up the hint, and trusted that she might
# Unrecognized Token ['muslin']
# Cound not evaluate perplexity of sent:  indeed, or a really new muslin in a shop window, could recall
# Unrecognized Token ['bowed']
# Cound not evaluate perplexity of sent:  from London Lydia came to enquire, and he bowed as they passed.
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  permission to introduce his friend, Mr. Wickham, who had returned
# Unrecognized Token ['pointedly']
# Cound not evaluate perplexity of sent:  utmost civility, but even pointedly included him in her
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet for a single evening during his visit were most
# Unrecognized Token ['chimney']
# Cound not evaluate perplexity of sent:  chimney-piece alone had cost eight hundred pounds, she felt all
# Unrecognized Token ['retail']
# Cound not evaluate perplexity of sent:  to retail it all among her neighbours as soon as she could. To
# Unrecognized Token ['estimated']
# Cound not evaluate perplexity of sent:  interruption, “that he or that any man should not be estimated
# Unrecognized Token ['military']
# Cound not evaluate perplexity of sent:  military life is not what I was intended for, but circumstances
# Unrecognized Token ['informality']
# Cound not evaluate perplexity of sent:  “There was just such an informality in the terms of the bequest
# Unrecognized Token ['conditional']
# Cound not evaluate perplexity of sent:  treat it as a merely conditional recommendation, and to assert
# Unrecognized Token ['revenge']
# Cound not evaluate perplexity of sent:  suspect him of descending to such malicious revenge, such
# Unrecognized Token ['inhumanity']
# Cound not evaluate perplexity of sent:  injustice, such inhumanity as this.”
# Unrecognized Token ['inmates']
# Cound not evaluate perplexity of sent:  greatest part of our youth was passed together; inmates of the
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  your uncle, Mr. Phillips, appears to do so much credit to—but he
# Unrecognized Token ['conversible']
# Cound not evaluate perplexity of sent:  not want abilities. He can be a conversible companion if he
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy.”
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  for neither Lydia nor Mr. Collins were once silent. Lydia talked
# Unrecognized Token ['misrepresented']
# Cound not evaluate perplexity of sent:  have perhaps misrepresented each to the other. It is, in short,
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  ceremony. If it be not so, let Mr. Darcy contradict it. Besides,
# Unrecognized Token ['unnecessarily']
# Cound not evaluate perplexity of sent:  she did not often speak unnecessarily to Mr. Collins, she could
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  not help asking him whether he intended to accept Mr. Bingley’s
# Unrecognized Token ['succession']
# Cound not evaluate perplexity of sent:  day of the ball, there was such a succession of rain as prevented
# Unrecognized Token ['injury']
# Cound not evaluate perplexity of sent:  forbearance, patience with Darcy, was injury to Wickham. She was
# Unrecognized Token ['illustration']
# Cound not evaluate perplexity of sent:  “Merely to the illustration of _your_ character,” said she,
# Unrecognized Token ['sketch']
# Cound not evaluate perplexity of sent:  that you were not to sketch my character at the present moment,
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy in a most infamous manner. I do not know the
# Unrecognized Token ['believes']
# Cound not evaluate perplexity of sent:  heard them from Mr. Darcy more than once, but he believes that it
# Unrecognized Token ['modest']
# Cound not evaluate perplexity of sent:  listened with delight to the happy, though modest hopes which
# Unrecognized Token ['unrestrained']
# Cound not evaluate perplexity of sent:  unrestrained wonder, and when at last Mr. Collins allowed him
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  with my reception. Mr. Darcy seemed much pleased with the
# Unrecognized Token ['patron']
# Cound not evaluate perplexity of sent:  offensive to his patron. He must write his own sermons; and the
# Unrecognized Token ['exhibition']
# Cound not evaluate perplexity of sent:  and her sister that some of the exhibition had escaped his
# Unrecognized Token ['guests']
# Cound not evaluate perplexity of sent:  behaviour to their guests. Darcy said nothing at all. Mr. Bennet,
# Unrecognized Token ['pressingly']
# Cound not evaluate perplexity of sent:  pressingly civil in her hope of seeing the whole family soon at
# Unrecognized Token ['gathering']
# Cound not evaluate perplexity of sent:  objection. Come, Kitty, I want you up stairs.” And, gathering her
# Unrecognized Token ['dissemble']
# Cound not evaluate perplexity of sent:  however your natural delicacy may lead you to dissemble; my
# Unrecognized Token ['qualification']
# Cound not evaluate perplexity of sent:  qualification.”
# Unrecognized Token ['manifold']
# Cound not evaluate perplexity of sent:  consideration, that in spite of your manifold attractions, it is
# Unrecognized Token ['qualifications']
# Cound not evaluate perplexity of sent:  qualifications. As I must therefore conclude that you are not
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  This information, however, startled Mrs. Bennet; she would have
# Unrecognized Token ['dismission']
# Cound not evaluate perplexity of sent:  objectionable in having accepted my dismission from your
# Unrecognized Token ['comfortless']
# Cound not evaluate perplexity of sent:  comfortless hotel. Many of my acquaintances are already there for
# Unrecognized Token ['deprive']
# Cound not evaluate perplexity of sent:  the loss of the three of whom we shall deprive you.”
# Unrecognized Token ['suspects']
# Cound not evaluate perplexity of sent:  indifference; and that if she suspects the nature of my feelings
# Unrecognized Token ['22']
# Cound not evaluate perplexity of sent:  Chapter 22
# Unrecognized Token ['eloquence']
# Cound not evaluate perplexity of sent:  and eloquence awaited her there.
# Unrecognized Token ['regained']
# Cound not evaluate perplexity of sent:  she soon regained her composure, and calmly replied:
# Unrecognized Token ['pang']
# Cound not evaluate perplexity of sent:  was a most humiliating picture! And to the pang of a friend
# Unrecognized Token ['unanswerable']
# Cound not evaluate perplexity of sent:  which he trusted would be an unanswerable argument with his
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet was really in a most pitiable state. The very mention
# Unrecognized Token ['complained']
# Cound not evaluate perplexity of sent:  dead. She complained bitterly of all this to her husband.
# Unrecognized Token ['24']
# Cound not evaluate perplexity of sent:  Chapter 24
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  difference of situation and temper. Consider Mr. Collins’s
# Unrecognized Token ['conjunction']
# Cound not evaluate perplexity of sent:  “Yes, in conjunction with his friend.”
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet still continued to wonder and repine at his returning
# Unrecognized Token ['peep']
# Cound not evaluate perplexity of sent:  moreover give her a peep at Jane; and, in short, as the time drew
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  not continue long. Mrs. Gardiner gave her the particulars also of
# Unrecognized Token ['conversations']
# Cound not evaluate perplexity of sent:  conversations occurring at different times between Jane and
# Unrecognized Token ['decorums']
# Cound not evaluate perplexity of sent:  elegant decorums which other people may observe. If _she_ does
# Unrecognized Token ['spleen']
# Cound not evaluate perplexity of sent:  disappointment and spleen. What are young men to rocks and
# Unrecognized Token ['28']
# Cound not evaluate perplexity of sent:  Chapter 28
# Unrecognized Token ['palings']
# Cound not evaluate perplexity of sent:  bring it in view. The palings of Rosings Park was their boundary
# Unrecognized Token ['gratify']
# Cound not evaluate perplexity of sent:  comfortable, she was not able to gratify him by any sigh of
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  From his garden, Mr. Collins would have led them round his two
# Unrecognized Token ['inspire']
# Cound not evaluate perplexity of sent:  to inspire, and was but slightly affected by his enumeration of
# Unrecognized Token ['echo']
# Cound not evaluate perplexity of sent:  enough recovered to echo whatever his son-in-law said, in a
# Unrecognized Token ['dictating']
# Cound not evaluate perplexity of sent:  dictating to others. In the intervals of her discourse with Mrs.
# Unrecognized Token ['instruction']
# Cound not evaluate perplexity of sent:  done in education without steady and regular instruction, and
# Unrecognized Token ['possessing']
# Cound not evaluate perplexity of sent:  comfortably settled, and of her possessing such a husband and
# Unrecognized Token ['gig']
# Cound not evaluate perplexity of sent:  in his gig, and showing him the country; but when he went away,
# Unrecognized Token ['counterpart']
# Cound not evaluate perplexity of sent:  the counterpart of the first. Their other engagements were few,
# Unrecognized Token ['disclaim']
# Cound not evaluate perplexity of sent:  Elizabeth had scarcely time to disclaim all right to the
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  handsome, but in person and address most truly the gentleman. Mr.
# Unrecognized Token ['curtseyed']
# Cound not evaluate perplexity of sent:  merely curtseyed to him without saying a word.
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy looked a little ashamed of his aunt’s ill-breeding, and
# Unrecognized Token ['stubbornness']
# Cound not evaluate perplexity of sent:  so well. There is a stubbornness about me that never can bear to
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “How very suddenly you all quitted Netherfield last November, Mr.
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “Mr. Collins appears to be very fortunate in his choice of a
# Unrecognized Token ['prudential']
# Cound not evaluate perplexity of sent:  perfectly happy, however, and in a prudential light it is
# Unrecognized Token ['ramble']
# Cound not evaluate perplexity of sent:  More than once did Elizabeth, in her ramble within the park,
# Unrecognized Token ['guardians']
# Cound not evaluate perplexity of sent:  “Are you indeed? And pray what sort of guardians do you make?
# Unrecognized Token ['tractable']
# Cound not evaluate perplexity of sent:  dare say she is one of the most tractable creatures in the world.
# Unrecognized Token ['mislead']
# Cound not evaluate perplexity of sent:  arrangement of them. If his own vanity, however, did not mislead
# Unrecognized Token ['overcoming']
# Cound not evaluate perplexity of sent:  your regard, can have little difficulty in overcoming it after
# Unrecognized Token ['calmness']
# Cound not evaluate perplexity of sent:  voice of forced calmness, he said:
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  As she pronounced these words, Mr. Darcy changed colour; but the
# Unrecognized Token ['remorse']
# Cound not evaluate perplexity of sent:  feeling of remorse. He even looked at her with a smile of
# Unrecognized Token ['awoke']
# Cound not evaluate perplexity of sent:  Elizabeth awoke the next morning to the same thoughts and
# Unrecognized Token ['retreating']
# Cound not evaluate perplexity of sent:  directly retreating. But the person who advanced was now near
# Unrecognized Token ['sheets']
# Cound not evaluate perplexity of sent:  increasing wonder, perceived an envelope containing two sheets of
# Unrecognized Token ['detaching']
# Cound not evaluate perplexity of sent:  was to be lost in detaching their brother, we shortly resolved on
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “Mr. Wickham is the son of a very respectable man, who had for
# Unrecognized Token ['cambridge']
# Cound not evaluate perplexity of sent:  father supported him at school, and afterwards at Cambridge—most
# Unrecognized Token ['dissolved']
# Cound not evaluate perplexity of sent:  thousand pounds. All connection between us seemed now dissolved.
# Unrecognized Token ['unprofitable']
# Cound not evaluate perplexity of sent:  unprofitable study, and was now absolutely resolved on being
# Unrecognized Token ['ordained']
# Cound not evaluate perplexity of sent:  ordained, if I would present him to the living in question—of
# Unrecognized Token ['revered']
# Cound not evaluate perplexity of sent:  not have forgotten my revered father’s intentions. You will
# Unrecognized Token ['revenging']
# Cound not evaluate perplexity of sent:  revenging himself on me was a strong inducement. His revenge
# Unrecognized Token ['clearer']
# Cound not evaluate perplexity of sent:  Wickham—when she read with somewhat clearer attention a relation
# Unrecognized Token ['grossest']
# Cound not evaluate perplexity of sent:  must be the grossest falsehood!”—and when she had gone through
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  so represent as to render Mr. Darcy’s conduct in it less than
# Unrecognized Token ['prejudiced']
# Cound not evaluate perplexity of sent:  partial, prejudiced, absurd.
# Unrecognized Token ['wretchedly']
# Cound not evaluate perplexity of sent:  Had I been in love, I could not have been more wretchedly blind!
# Unrecognized Token ['barouche']
# Cound not evaluate perplexity of sent:  barouche-box, there will be very good room for one of you—and
# Unrecognized Token ['heavier']
# Cound not evaluate perplexity of sent:  yet heavier chagrin. They were hopeless of remedy. Her father,
# Unrecognized Token ['forever']
# Cound not evaluate perplexity of sent:  would be going there forever.
# Unrecognized Token ['gratify']
# Cound not evaluate perplexity of sent:  highly gratify whatever of her own vanity she had not yet been
# Unrecognized Token ['boxes']
# Cound not evaluate perplexity of sent:  their boxes, work-bags, and parcels, and the unwelcome addition
# Unrecognized Token ['blinds']
# Cound not evaluate perplexity of sent:  such fun! As we went along, Kitty and I drew up the blinds, and
# Unrecognized Token ['nicest']
# Cound not evaluate perplexity of sent:  the other three with the nicest cold luncheon in the world, and
# Unrecognized Token ['encumbrance']
# Cound not evaluate perplexity of sent:  off this last encumbrance of mystery. “And then,” said she, “if
# Unrecognized Token ['pitiful']
# Cound not evaluate perplexity of sent:  list of pitiful fellows who have been kept aloof by Lydia’s
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Bennet saw that her whole heart was in the subject, and
# Unrecognized Token ['vexations']
# Cound not evaluate perplexity of sent:  vexations by dwelling on them. She was confident of having
# Unrecognized Token ['unavoidable']
# Cound not evaluate perplexity of sent:  performed her duty, and to fret over unavoidable evils, or
# Unrecognized Token ['earthly']
# Cound not evaluate perplexity of sent:  visit to Brighton comprised every possibility of earthly
# Unrecognized Token ['tens']
# Cound not evaluate perplexity of sent:  the object of attention, to tens and to scores of them at present
# Unrecognized Token ['dazzling']
# Cound not evaluate perplexity of sent:  and the gay, and dazzling with scarlet; and, to complete the
# Unrecognized Token ['gentlest']
# Cound not evaluate perplexity of sent:  gentlest of accents:
# Unrecognized Token ['clamorous']
# Cound not evaluate perplexity of sent:  to believe would be well attended to; and in the clamorous
# Unrecognized Token ['chatsworth']
# Cound not evaluate perplexity of sent:  the celebrated beauties of Matlock, Chatsworth, Dovedale, or the
# Unrecognized Token ['impunity']
# Cound not evaluate perplexity of sent:  county with impunity, and rob it of a few petrified spars without
# Unrecognized Token ['birmingham']
# Cound not evaluate perplexity of sent:  Birmingham, etc. are sufficiently known. A small part of
# Unrecognized Token ['alarms']
# Cound not evaluate perplexity of sent:  last question—and her alarms now being removed, she was at
# Unrecognized Token ['proportioned']
# Cound not evaluate perplexity of sent:  well proportioned room, handsomely fitted up. Elizabeth, after
# Unrecognized Token ['winding']
# Cound not evaluate perplexity of sent:  winding of the valley, as far as she could trace it, with
# Unrecognized Token ['bedrooms']
# Cound not evaluate perplexity of sent:  The picture-gallery, and two or three of the principal bedrooms,
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy, with such a smile over the face as she remembered to
# Unrecognized Token ['calmness']
# Cound not evaluate perplexity of sent:  to speak with calmness, if he really intended to meet them. For a
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  most sport. Mrs. Gardiner, who was walking arm-in-arm with
# Unrecognized Token ['construction']
# Cound not evaluate perplexity of sent:  capable of a very different construction; and that his character
# Unrecognized Token ['unbending']
# Cound not evaluate perplexity of sent:  please, so free from self-consequence or unbending reserve, as
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  arose to depart, Mr. Darcy called on his sister to join him in
# Unrecognized Token ['inhabitants']
# Cound not evaluate perplexity of sent:  had, and if not, it would certainly be imputed by the inhabitants
# Unrecognized Token ['patron']
# Cound not evaluate perplexity of sent:  concerns with the son of his patron were imperfectly understood,
# Unrecognized Token ['hatred']
# Cound not evaluate perplexity of sent:  No; hatred had vanished long ago, and she had almost as long been
# Unrecognized Token ['goodwill']
# Cound not evaluate perplexity of sent:  goodwill which could not be overlooked. It was gratitude;
# Unrecognized Token ['predominate']
# Cound not evaluate perplexity of sent:  to predominate, she began to regret that he came.
# Unrecognized Token ['exerting']
# Cound not evaluate perplexity of sent:  her a moment’s distress; but exerting herself vigorously to repel
# Unrecognized Token ['discompose']
# Cound not evaluate perplexity of sent:  from the hint; but she had merely intended to discompose
# Unrecognized Token ['w']
# Cound not evaluate perplexity of sent:  his belief that W. never intended to go there, or to marry Lydia
# Unrecognized Token ['b']
# Cound not evaluate perplexity of sent:  the alarm, set off from B. intending to trace their route. He did
# Unrecognized Token ['kindest']
# Cound not evaluate perplexity of sent:  pass through. With the kindest concern he came on to Longbourn,
# Unrecognized Token ['losing']
# Cound not evaluate perplexity of sent:  without losing a moment of the time so precious; but as she
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Gardiner this moment, on business that cannot be delayed; I
# Unrecognized Token ['knees']
# Cound not evaluate perplexity of sent:  Elizabeth hesitated, but her knees trembled under her and she
# Unrecognized Token ['miserably']
# Cound not evaluate perplexity of sent:  and looking so miserably ill, that it was impossible for Darcy to
# Unrecognized Token ['consolatory']
# Cound not evaluate perplexity of sent:  the belief of his self-conquest brought nothing consolatory to
# Unrecognized Token ['promoted']
# Cound not evaluate perplexity of sent:  the perverseness of those feelings which would now have promoted
# Unrecognized Token ['fluctuating']
# Cound not evaluate perplexity of sent:  had continually been fluctuating but never without an object. The
# Unrecognized Token ['trembling']
# Cound not evaluate perplexity of sent:  postscript of the last with trembling energy.— Though Lydia had
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Gardiner promised every assistance in his power. Elizabeth,
# Unrecognized Token ['notes']
# Cound not evaluate perplexity of sent:  the rest there were notes to be written to all their friends at
# Unrecognized Token ['brightening']
# Cound not evaluate perplexity of sent:  “Do you really think so?” cried Elizabeth, brightening up for a
# Unrecognized Token ['favourites']
# Cound not evaluate perplexity of sent:  favourites.”
# Unrecognized Token ['invectives']
# Cound not evaluate perplexity of sent:  expected; with tears and lamentations of regret, invectives
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  above all, keep Mr. Bennet from fighting. Tell him what a
# Unrecognized Token ['vent']
# Cound not evaluate perplexity of sent:  her to vent all her feelings on the housekeeper, who attended in
# Unrecognized Token ['sally']
# Cound not evaluate perplexity of sent:  would tell Sally to mend a great slit in my worked muslin gown
# Unrecognized Token ['condolence']
# Cound not evaluate perplexity of sent:  impossible; condolence insufferable. Let them triumph over us at
# Unrecognized Token ['finances']
# Cound not evaluate perplexity of sent:  own finances, there was a very powerful motive for secrecy, in
# Unrecognized Token ['transpired']
# Cound not evaluate perplexity of sent:  had just transpired that he had left gaming debts behind him to a
# Unrecognized Token ['gamester']
# Cound not evaluate perplexity of sent:  them with horror. “A gamester!” she cried. “This is wholly
# Unrecognized Token ['prohibited']
# Cound not evaluate perplexity of sent:  village. Balls will be absolutely prohibited, unless you stand up
# Unrecognized Token ['concluding']
# Cound not evaluate perplexity of sent:  housekeeper coming towards them, and, concluding that she came to
# Unrecognized Token ['sixpence']
# Cound not evaluate perplexity of sent:  them, because Wickham has not sixpence of his own. The kindness
# Unrecognized Token ['requited']
# Cound not evaluate perplexity of sent:  of my uncle and aunt can never be requited. Their taking her
# Unrecognized Token ['dictate']
# Cound not evaluate perplexity of sent:  that I am sure I can’t write; so I will dictate, and you write
# Unrecognized Token ['calico']
# Cound not evaluate perplexity of sent:  She was then proceeding to all the particulars of calico, muslin,
# Unrecognized Token ['refuge']
# Cound not evaluate perplexity of sent:  folly, took refuge in her own room, that she might think with
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  When first Mr. Bennet had married, economy was held to be
# Unrecognized Token ['proportions']
# Cound not evaluate perplexity of sent:  Bennet and the children. But in what proportions it should be
# Unrecognized Token ['ashworth']
# Cound not evaluate perplexity of sent:  but Ashworth is too far off! I could not bear to have her ten
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  “Mrs. Bennet, before you take any or all of these houses for your
# Unrecognized Token ['frailty']
# Cound not evaluate perplexity of sent:  of a sister’s frailty would have mortified her so much—not,
# Unrecognized Token ['individually']
# Cound not evaluate perplexity of sent:  however, from any fear of disadvantage from it individually to
# Unrecognized Token ['gulf']
# Cound not evaluate perplexity of sent:  herself, for, at any rate, there seemed a gulf impassable between
# Unrecognized Token ['precluding']
# Cound not evaluate perplexity of sent:  tendency, and precluding the possibility of the other, was soon
# Unrecognized Token ['passions']
# Cound not evaluate perplexity of sent:  because their passions were stronger than their virtue, she could
# Unrecognized Token ['stepped']
# Cound not evaluate perplexity of sent:  open, and she ran into the room. Her mother stepped forwards,
# Unrecognized Token ['impudent']
# Cound not evaluate perplexity of sent:  impudent man. _She_ blushed, and Jane blushed; but the cheeks of
# Unrecognized Token ['bowed']
# Cound not evaluate perplexity of sent:  ring, and then I bowed and smiled like anything.”
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  hear herself called “Mrs. Wickham” by each of them; and in the
# Unrecognized Token ['kill']
# Cound not evaluate perplexity of sent:  did every thing best in the world; and she was sure he would kill
# Unrecognized Token ['distracted']
# Cound not evaluate perplexity of sent:  should have gone quite distracted. And there was my aunt, all the
# Unrecognized Token ['benches']
# Cound not evaluate perplexity of sent:  benches and prepared to be happy; for the length of the letter
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  been. He came to tell Mr. Gardiner that he had found out where
# Unrecognized Token ['remedy']
# Cound not evaluate perplexity of sent:  endeavour to remedy an evil which had been brought on by himself.
# Unrecognized Token ['amounting']
# Cound not evaluate perplexity of sent:  young people. His debts are to be paid, amounting, I believe, to
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “Mr. Darcy was punctual in his return, and as Lydia informed you,
# Unrecognized Token ['supplication']
# Cound not evaluate perplexity of sent:  research; in which supplication had been necessary to a woman
# Unrecognized Token ['ramble']
# Cound not evaluate perplexity of sent:  “I am afraid I interrupt your solitary ramble, my dear sister?”
# Unrecognized Token ['sermons']
# Cound not evaluate perplexity of sent:  “How should you have liked making sermons?”
# Unrecognized Token ['ducks']
# Cound not evaluate perplexity of sent:  three couple of ducks just fit to be killed.”
# Unrecognized Token ['paler']
# Cound not evaluate perplexity of sent:  door. Jane looked a little paler than usual, but more sedate than
# Unrecognized Token ['contrasted']
# Cound not evaluate perplexity of sent:  two daughters ashamed, especially when contrasted with the cold
# Unrecognized Token ['northward']
# Cound not evaluate perplexity of sent:  They are gone down to Newcastle, a place quite northward, it
# Unrecognized Token ['covies']
# Cound not evaluate perplexity of sent:  to oblige you, and will save all the best of the covies for you.”
# Unrecognized Token ['sanction']
# Cound not evaluate perplexity of sent:  imagined that Bingley had received his sanction to be happy, had
# Unrecognized Token ['unfelt']
# Cound not evaluate perplexity of sent:  that his kindness was neither unknown nor unfelt by the whole of
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  better than what we had at the Lucases’ last week; and even Mr.
# Unrecognized Token ['confidante']
# Cound not evaluate perplexity of sent:  make _me_ your confidante.”
# Unrecognized Token ['innocently']
# Cound not evaluate perplexity of sent:  observe her; and when at last Kitty did, she very innocently
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet’s schemes for this day were ineffectual. Bingley was
# Unrecognized Token ['tempers']
# Cound not evaluate perplexity of sent:  your doing very well together. Your tempers are by no means
# Unrecognized Token ['vex']
# Cound not evaluate perplexity of sent:  ever heard you utter. Good girl! It would vex me, indeed, to see
# Unrecognized Token ['shift']
# Cound not evaluate perplexity of sent:  have your happiness. No, no, let me shift for myself; and,
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  perhaps, if I have very good luck, I may meet with another Mr.
# Unrecognized Token ['preceded']
# Cound not evaluate perplexity of sent:  neither the carriage, nor the livery of the servant who preceded
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet and Kitty, though she was perfectly unknown to them,
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet, with great civility, begged her ladyship to take
# Unrecognized Token ['untitled']
# Cound not evaluate perplexity of sent:  untitled—families. Their fortune on both sides is splendid. They
# Unrecognized Token ['aunts']
# Cound not evaluate perplexity of sent:  Who are your uncles and aunts? Do not imagine me ignorant of
# Unrecognized Token ['solid']
# Cound not evaluate perplexity of sent:  sense and solid reasoning.
# Unrecognized Token ['unblemished']
# Cound not evaluate perplexity of sent:  be as happy as dignity unblemished could make him. In that case
# Unrecognized Token ['undetermined']
# Cound not evaluate perplexity of sent:  instead of the aunt; and she was undetermined whether most to be
# Unrecognized Token ['illustrious']
# Cound not evaluate perplexity of sent:  illustrious personages in this land.’
# Unrecognized Token ['termed']
# Cound not evaluate perplexity of sent:  she termed so disgraceful a match. I thought it my duty to give
# Unrecognized Token ['speediest']
# Cound not evaluate perplexity of sent:  the speediest intelligence of this to my cousin, that she and her
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  as I abominate writing, I would not give up Mr. Collins’s
# Unrecognized Token ['premises']
# Cound not evaluate perplexity of sent:  accusations were ill-founded, formed on mistaken premises, my
# Unrecognized Token ['charity']
# Cound not evaluate perplexity of sent:  The adieu is charity itself. But think no more of the letter. The
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  reading Mr. Collins’s letter; and after laughing at her some
# Unrecognized Token ['theirs']
# Cound not evaluate perplexity of sent:  always been evident to her that such an income as theirs, under
# Unrecognized Token ['bills']
# Cound not evaluate perplexity of sent:  towards discharging their bills. Their manner of living, even
# Unrecognized Token ['offence']
# Cound not evaluate perplexity of sent:  overlook the offence, and seek a reconciliation; and, after a
# Unrecognized Token ['redistribution']
# Cound not evaluate perplexity of sent:  by U.S. copyright law. Redistribution is subject to the trademark
# Unrecognized Token ['destroy']
# Cound not evaluate perplexity of sent:  destroy all copies of Project Gutenberg-tm electronic works in your
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  electronic works. See paragraph 1.E below.
# Unrecognized Token ['pglaf']
# Cound not evaluate perplexity of sent:  Foundation" or PGLAF), owns a compilation copyright in the collection
# Unrecognized Token ['linked']
# Cound not evaluate perplexity of sent:  will be linked to the Project Gutenberg-tm License for all works
# Unrecognized Token ['compressed']
# Cound not evaluate perplexity of sent:  compressed, marked up, nonproprietary or proprietary form, including
# Unrecognized Token ['exporting']
# Cound not evaluate perplexity of sent:  to the user, provide a copy, a means of exporting a copy, or a means
# Unrecognized Token ['60']
# Cound not evaluate perplexity of sent:  within 60 days following each date on which you prepare (or are
# Unrecognized Token ['destroy']
# Cound not evaluate perplexity of sent:  License. You must require such a user to return or destroy all
# Unrecognized Token ['disclaim']
# Cound not evaluate perplexity of sent:  Gutenberg-tm electronic work under this agreement, disclaim all
# Unrecognized Token ['distributor']
# Cound not evaluate perplexity of sent:  TRADEMARK OWNER, AND ANY DISTRIBUTOR UNDER THIS AGREEMENT WILL NOT BE
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  1.F.3. LIMITED RIGHT OF REPLACEMENT OR REFUND - If you discover a
# Unrecognized Token ['violates']
# Cound not evaluate perplexity of sent:  violates the law of the state applicable to this agreement, the
# Unrecognized Token ['b']
# Cound not evaluate perplexity of sent:  or any Project Gutenberg-tm work, (b) alteration, modification, or
# Unrecognized Token ['3']
# Cound not evaluate perplexity of sent:  Section 3. Information about the Project Gutenberg Literary
# Unrecognized Token ['mississippi']
# Cound not evaluate perplexity of sent:  state of Mississippi and granted tax exempt status by the Internal
# Unrecognized Token ['machine']
# Cound not evaluate perplexity of sent:  freely distributed in machine-readable form accessible by the widest
# Unrecognized Token ['methods']
# Cound not evaluate perplexity of sent:  methods and addresses. Donations are accepted in a number of other
# Unrecognized Token ['checks']
# Cound not evaluate perplexity of sent:  ways including checks, online payments and credit card donations. To
# Unrecognized Token ['professor']
# Cound not evaluate perplexity of sent:  Professor Michael S. Hart was the originator of the Project
# Unrecognized Token ['u']
# Cound not evaluate perplexity of sent:  the U.S. unless a copyright notice is included. Thus, we do not
# Unrecognized Token ['main']
# Cound not evaluate perplexity of sent:  Most people start at our website which has the main PG search
# Cleaning text...
# Breaking to sentences
# Extracting tokens...
# 100%|██████████| 5747/5747 [00:00<00:00, 69815.98it/s]
# Removing unacceptible tokens...
# Counting tokens...
# Computing frequencies...
# Unrecognized Token ['surrounding']
# Cound not evaluate perplexity of sent:  fixed in the minds of the surrounding families, that he is
# Unrecognized Token ['solace']
# Cound not evaluate perplexity of sent:  solace was visiting and news.
# Unrecognized Token ['coughs']
# Cound not evaluate perplexity of sent:  “Kitty has no discretion in her coughs,” said her father; “she
# Unrecognized Token ['ascertaining']
# Cound not evaluate perplexity of sent:  ascertaining from an upper window, that he wore a blue coat and
# Unrecognized Token ['popularity']
# Cound not evaluate perplexity of sent:  the tide of his popularity; for he was discovered to be proud, to
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy, looking at the eldest Miss Bennet.
# Unrecognized Token ['sixth']
# Cound not evaluate perplexity of sent:  with Jane again, and the two sixth with Lizzy, and the
# Unrecognized Token ['pliancy']
# Cound not evaluate perplexity of sent:  general; and with more quickness of observation and less pliancy
# Unrecognized Token ['unassailed']
# Cound not evaluate perplexity of sent:  of temper than her sister, and with a judgment too unassailed by
# Unrecognized Token ['associating']
# Cound not evaluate perplexity of sent:  of associating with people of rank; and were therefore in every
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Bingley inherited property to the amount of nearly a hundred
# Unrecognized Token ['reasonableness']
# Cound not evaluate perplexity of sent:  degree of her own regard, nor of its reasonableness. She has known
# Unrecognized Token ['dispositions']
# Cound not evaluate perplexity of sent:  matter of chance. If the dispositions of the parties are ever so
# Unrecognized Token ['dark']
# Cound not evaluate perplexity of sent:  uncommonly intelligent by the beautiful expression of her dark
# Unrecognized Token ['unaware']
# Cound not evaluate perplexity of sent:  unaware;—to her he was only the man who made himself agreeable
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Darcy, with grave propriety, requested to be allowed the
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  reflections. Mr. Darcy replied with great intrepidity,
# Unrecognized Token ['silliest']
# Cound not evaluate perplexity of sent:  be two of the silliest girls in the country. I have suspected it
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  servant waited for an answer. Mrs. Bennet’s eyes sparkled with
# Unrecognized Token ['wives']
# Cound not evaluate perplexity of sent:  of one of the officers’ wives, and Elizabeth continued her walk
# Unrecognized Token ['ragout']
# Cound not evaluate perplexity of sent:  cards; who, when he found her prefer a plain dish to a ragout,
# Unrecognized Token ['assent']
# Cound not evaluate perplexity of sent:  their hearty assent, and indulged their mirth for some time at
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Hurst and Miss Bingley both cried out against the injustice
# Unrecognized Token ['meanness']
# Cound not evaluate perplexity of sent:  addressed, “there is meanness in _all_ the arts which ladies
# Unrecognized Token ['victory']
# Cound not evaluate perplexity of sent:  gained a complete victory over him, continued her triumph.
# Unrecognized Token ['neighbourhoods']
# Cound not evaluate perplexity of sent:  are few neighbourhoods larger. I know we dine with
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  result of it was, that the youngest should tax Mr. Bingley with
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet and her daughters then departed, and Elizabeth
# Unrecognized Token ['witticisms']
# Cound not evaluate perplexity of sent:  their censure of _her_, in spite of all Miss Bingley’s witticisms
# Unrecognized Token ['perpetual']
# Cound not evaluate perplexity of sent:  perpetual commendations of the lady either on his handwriting,
# Unrecognized Token ['syllables']
# Cound not evaluate perplexity of sent:  much for words of four syllables. Do not you, Darcy?”
# Unrecognized Token ['correspondents']
# Cound not evaluate perplexity of sent:  correspondents.”
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “Your humility, Mr. Bingley,” said Elizabeth, “must disarm
# Unrecognized Token ['requester']
# Cound not evaluate perplexity of sent:  of friendship and affection. A regard for the requester would
# Unrecognized Token ['subsisting']
# Cound not evaluate perplexity of sent:  intimacy subsisting between the parties?”
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  by a lively Scotch air; and soon afterwards Mr. Darcy, drawing
# Unrecognized Token ['gaily']
# Cound not evaluate perplexity of sent:  She then ran gaily off, rejoicing as she rambled about, in the
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  They were not welcomed home very cordially by their mother. Mrs.
# Unrecognized Token ['rail']
# Cound not evaluate perplexity of sent:  she continued to rail bitterly against the cruelty of settling an
# Unrecognized Token ['disagreement']
# Cound not evaluate perplexity of sent:  “The disagreement subsisting between yourself and my late
# Unrecognized Token ['bounty']
# Cound not evaluate perplexity of sent:  Lewis de Bourgh, whose bounty and beneficence has preferred me to
# Unrecognized Token ['discourage']
# Cound not evaluate perplexity of sent:  person to discourage him.”
# Unrecognized Token ['quarreled']
# Cound not evaluate perplexity of sent:  but Mrs. Bennet, who quarreled with no compliments, answered most
# Unrecognized Token ['oddly']
# Cound not evaluate perplexity of sent:  settled so oddly.”
# Unrecognized Token ['heiress']
# Cound not evaluate perplexity of sent:  “She has only one daughter, the heiress of Rosings, and of very
# Unrecognized Token ['condescends']
# Cound not evaluate perplexity of sent:  with them. But she is perfectly amiable, and often condescends to
# Unrecognized Token ['duchess']
# Cound not evaluate perplexity of sent:  seemed born to be a duchess, and that the most elevated rank,
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Bennet’s expectations were fully answered. His cousin was as
# Unrecognized Token ['novels']
# Cound not evaluate perplexity of sent:  protested that he never read novels. Kitty stared at him, and
# Unrecognized Token ['richard']
# Cound not evaluate perplexity of sent:  Richard; and if he does, Colonel Forster will hire him. My aunt
# Unrecognized Token ['stamp']
# Cound not evaluate perplexity of sent:  books of a serious stamp, though written solely for their
# Unrecognized Token ['advantageous']
# Cound not evaluate perplexity of sent:  nothing so advantageous to them as instruction. But I will no
# Unrecognized Token ['illiterate']
# Cound not evaluate perplexity of sent:  an illiterate and miserly father; and though he belonged to one
# Unrecognized Token ['universities']
# Cound not evaluate perplexity of sent:  of the universities, he had merely kept the necessary terms,
# Unrecognized Token ['veneration']
# Cound not evaluate perplexity of sent:  felt for her high rank, and his veneration for her as his
# Unrecognized Token ['eligibility']
# Cound not evaluate perplexity of sent:  an excellent one, full of eligibility and suitableness, and
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Collins had only to change from Jane to Elizabeth—and it was
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  the same spot. Mr. Denny addressed them directly, and entreated
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  young ladies who introduced him to her notice. Mrs. Phillips was
# Unrecognized Token ['rivals']
# Cound not evaluate perplexity of sent:  With such rivals for the notice of the fair as Mr. Wickham and
# ...
# Cound not evaluate perplexity of sent:  possible to myself; and if I endeavour to undeceive people as to
# Unrecognized Token ['fervently']
# Cound not evaluate perplexity of sent:  fervently did she value his remembrance, and prefer him to every
# Unrecognized Token ['miller']
# Cound not evaluate perplexity of sent:  Colonel Miller’s regiment went away. I thought I should have
# Unrecognized Token ['anew']
# Cound not evaluate perplexity of sent:  sense of pleasure was lost in shame. She felt anew the justice of
# Unrecognized Token ['ecstasy']
# Cound not evaluate perplexity of sent:  ecstasy, calling for everyone’s congratulations, and laughing and
# Unrecognized Token ['luckless']
# Cound not evaluate perplexity of sent:  talking with more violence than ever; whilst the luckless Kitty
# Unrecognized Token ['peevish']
# Cound not evaluate perplexity of sent:  unreasonable as her accent was peevish.
# Unrecognized Token ['absurdity']
# Cound not evaluate perplexity of sent:  little absurdity are not worth a regret. Come, let me see the
# Unrecognized Token ['volatility']
# Cound not evaluate perplexity of sent:  be affected by the wild volatility, the assurance and disdain of
# Unrecognized Token ['tent']
# Cound not evaluate perplexity of sent:  view, she saw herself seated beneath a tent, tenderly flirting
# Unrecognized Token ['contributed']
# Cound not evaluate perplexity of sent:  indebted, than as her ignorance and folly had contributed to his
# Unrecognized Token ['philosopher']
# Cound not evaluate perplexity of sent:  entertainment are wanting, the true philosopher will derive
# Unrecognized Token ['ceaseless']
# Cound not evaluate perplexity of sent:  would be certain. But here, by carrying with me one ceaseless
# Unrecognized Token ['realised']
# Cound not evaluate perplexity of sent:  have all my expectations of pleasure realised. A scheme of which
# Unrecognized Token ['curtailed']
# Cound not evaluate perplexity of sent:  commencement and curtailed its extent. Mr. Gardiner would be
# Unrecognized Token ['peak']
# Cound not evaluate perplexity of sent:  Peak.
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  inclination to see the place again. Mr. Gardiner declared his
# Unrecognized Token ['lowest']
# Cound not evaluate perplexity of sent:  They entered it in one of its lowest points, and drove for some
# Unrecognized Token ['swelled']
# Cound not evaluate perplexity of sent:  a stream of some natural importance was swelled into greater, but
# Unrecognized Token ['smilingly']
# Cound not evaluate perplexity of sent:  miniatures, over the mantelpiece. Her aunt asked her, smilingly,
# Unrecognized Token ['plays']
# Cound not evaluate perplexity of sent:  accomplished!—She plays and sings all day long. In the next room
# Unrecognized Token ['goes']
# Cound not evaluate perplexity of sent:  “Except,” thought Elizabeth, “when she goes to Ramsgate.”
# Unrecognized Token ['instinctively']
# Cound not evaluate perplexity of sent:  She had instinctively turned away; but stopping on his approach,
# Unrecognized Token ['hanging']
# Cound not evaluate perplexity of sent:  them again, after some time, in a descent among hanging woods, to
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Gardiner was standing a little behind; and on her pausing,
# Unrecognized Token ['inadequate']
# Cound not evaluate perplexity of sent:  morning, found Elizabeth’s arm inadequate to her support, and
# Unrecognized Token ['bakewell']
# Cound not evaluate perplexity of sent:  before we left Bakewell, we understood that you were not
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  others, and when they had reached the carriage, Mr. and Mrs.
# Unrecognized Token ['naming']
# Cound not evaluate perplexity of sent:  which they had been connected, without actually naming her
# Unrecognized Token ['satisfactions']
# Cound not evaluate perplexity of sent:  spent in the satisfactions of an intercourse renewed after many
# Unrecognized Token ['rival']
# Cound not evaluate perplexity of sent:  been set up as a rival to Jane. No look appeared on either side
# Unrecognized Token ['untinctured']
# Cound not evaluate perplexity of sent:  recollection of Jane not untinctured by tenderness, and a wish of
# Unrecognized Token ['26th']
# Cound not evaluate perplexity of sent:  months. We have not met since the 26th of November, when we were
# Unrecognized Token ['avoidance']
# Cound not evaluate perplexity of sent:  this studied avoidance spoke rather a momentary embarrassment
# Unrecognized Token ['rejected']
# Cound not evaluate perplexity of sent:  rejected. Neither had anything occurred in the intelligence of
# Unrecognized Token ['brevity']
# Cound not evaluate perplexity of sent:  indifference and brevity, and the other said no more.
# Unrecognized Token ['cake']
# Cound not evaluate perplexity of sent:  entrance of servants with cold meat, cake, and a variety of all
# Unrecognized Token ['tanned']
# Cound not evaluate perplexity of sent:  alteration than her being rather tanned, no miraculous
# Unrecognized Token ['nose']
# Cound not evaluate perplexity of sent:  nose wants character—there is nothing marked in its lines. Her
# Unrecognized Token ['sadly']
# Cound not evaluate perplexity of sent:  give her nothing. Our poor mother is sadly grieved. My father
# Unrecognized Token ['satisfying']
# Cound not evaluate perplexity of sent:  their niece was taken suddenly ill; but satisfying them instantly
# Unrecognized Token ['disclose']
# Cound not evaluate perplexity of sent:  disclose the real truth? Oh, that I knew how it was!”
# Unrecognized Token ['unprotected']
# Cound not evaluate perplexity of sent:  girl who is by no means unprotected or friendless, and who was
# Unrecognized Token ['economically']
# Cound not evaluate perplexity of sent:  economically, though less expeditiously, married in London than
# Unrecognized Token ['profligate']
# Cound not evaluate perplexity of sent:  he has been profligate in every sense of the word; that he has
# Unrecognized Token ['beatings']
# Cound not evaluate perplexity of sent:  in my side and pains in my head, and such beatings at heart, that
# Unrecognized Token ['seclusion']
# Cound not evaluate perplexity of sent:  real occasion for such a seclusion from the family, they did not
# Unrecognized Token ['incurred']
# Cound not evaluate perplexity of sent:  incurred in this business, had given more of fretfulness than
# Unrecognized Token ['48']
# Cound not evaluate perplexity of sent:  Chapter 48
# Unrecognized Token ['title']
# Cound not evaluate perplexity of sent:  all honoured with the title of seduction, had been extended into
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  before they procured lodgings. Mr. Gardiner himself did not
# Unrecognized Token ['grand']
# Cound not evaluate perplexity of sent:  of letters was the grand object of every morning’s impatience.
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet, I am inclined to think that her own disposition must
# Unrecognized Token ['apprehending']
# Cound not evaluate perplexity of sent:  related the affair. They agree with me in apprehending that this
# Unrecognized Token ['august']
# Cound not evaluate perplexity of sent:  “Gracechurch Street, _Monday, August_ 2.
# Unrecognized Token ['clearing']
# Cound not evaluate perplexity of sent:  her. Though our kind uncle has done something towards clearing
# Unrecognized Token ['fidgety']
# Cound not evaluate perplexity of sent:  been fidgety from alarm and vexation. To know that her daughter
# Unrecognized Token ['annual']
# Cound not evaluate perplexity of sent:  annual sum for the better provision of his children, and of his
# Unrecognized Token ['acceding']
# Cound not evaluate perplexity of sent:  acceding to the proposal before him. In terms of grateful
# Unrecognized Token ['rejected']
# Cound not evaluate perplexity of sent:  rejected many as deficient in size and importance.
# Unrecognized Token ['stoke']
# Cound not evaluate perplexity of sent:  it—or the great house at Stoke, if the drawing-room were larger;
# Unrecognized Token ['pulvis']
# Cound not evaluate perplexity of sent:  miles from me; and as for Pulvis Lodge, the attics are dreadful.”
# Unrecognized Token ['confidently']
# Cound not evaluate perplexity of sent:  were few people on whose secrecy she would have more confidently
# Unrecognized Token ['gladly']
# Cound not evaluate perplexity of sent:  would now have been most gladly and gratefully received! He was
# Unrecognized Token ['mildly']
# Cound not evaluate perplexity of sent:  mildly, to receive her and her husband at Longbourn, as soon as
# Unrecognized Token ['demanding']
# Cound not evaluate perplexity of sent:  from sister to sister, demanding their congratulations; and when
# Unrecognized Token ['birds']
# Cound not evaluate perplexity of sent:  more birds on the first of September, than any body else in the
# Unrecognized Token ['managed']
# Cound not evaluate perplexity of sent:  Are not you curious to hear how it was managed?”
# Unrecognized Token ['ll']
# Cound not evaluate perplexity of sent:  them. If you’ll believe me, I did not once put my foot out of
# Unrecognized Token ['sept']
# Cound not evaluate perplexity of sent:  “Gracechurch Street, _Sept_. 6.
# Unrecognized Token ['confide']
# Cound not evaluate perplexity of sent:  impossible for any young woman of character to love or confide in
# Unrecognized Token ['consequences']
# Cound not evaluate perplexity of sent:  to lay all the ill-consequences of Lydia’s flight on her own
# Unrecognized Token ['overtaken']
# Cound not evaluate perplexity of sent:  overtaken by Wickham.
# Unrecognized Token ['silenced']
# Cound not evaluate perplexity of sent:  silenced him; but he soon afterwards said:
# Unrecognized Token ['retirement']
# Cound not evaluate perplexity of sent:  for me! The quiet, the retirement of such a life would have
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Bingley arrived. Mrs. Bennet, through the assistance of
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  “Good gracious! Mr. Darcy!—and so it does, I vow. Well, any
# Unrecognized Token ['levelled']
# Cound not evaluate perplexity of sent:  Elizabeth, who knew this to be levelled at Mr. Darcy, was in such
# Unrecognized Token ['birds']
# Cound not evaluate perplexity of sent:  “When you have killed all your own birds, Mr. Bingley,” said her
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  When the gentlemen rose to go away, Mrs. Bennet was mindful of
# Unrecognized Token ['deaden']
# Cound not evaluate perplexity of sent:  those subjects that must deaden them more. Mr. Darcy’s behaviour
# Unrecognized Token ['ungraciousness']
# Cound not evaluate perplexity of sent:  whenever they did. Her mother’s ungraciousness, made the sense of
# Unrecognized Token ['enabling']
# Cound not evaluate perplexity of sent:  pass away without enabling them to enter into something more of
# Unrecognized Token ['cup']
# Cound not evaluate perplexity of sent:  coffee cup himself; and she seized the opportunity of saying:
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet, in short, was in very great spirits; she had seen
# Unrecognized Token ['instruct']
# Cound not evaluate perplexity of sent:  love to instruct, though we can teach only what is not worth
# Unrecognized Token ['waste']
# Cound not evaluate perplexity of sent:  still five minutes longer; but unable to waste such a precious
# Unrecognized Token ['premeditation']
# Cound not evaluate perplexity of sent:  such premeditation, and her entreaty that _she_ would not give in
# Unrecognized Token ['officiousness']
# Cound not evaluate perplexity of sent:  officiousness of the mother, and heard all her silly remarks with
# Unrecognized Token ['super']
# Cound not evaluate perplexity of sent:  excellent understanding, and super-excellent disposition of Jane,
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  Mrs. Bennet could not give her consent or speak her approbation
# Unrecognized Token ['contradicted']
# Cound not evaluate perplexity of sent:  contradicted.”
# Unrecognized Token ['unallied']
# Cound not evaluate perplexity of sent:  no importance in the world, and wholly unallied to the family! Do
# Unrecognized Token ['brooking']
# Cound not evaluate perplexity of sent:  habit of brooking disappointment.”
# Unrecognized Token ['weakest']
# Cound not evaluate perplexity of sent:  his aunt would address him on his weakest side. With his notions
# Unrecognized Token ['dismay']
# Cound not evaluate perplexity of sent:  with dismay all the consequent explanations.
# Unrecognized Token ['mr']
# Cound not evaluate perplexity of sent:  Mr. Collins moreover adds, ‘I am truly rejoiced that my cousin
# Unrecognized Token ['unexampled']
# Cound not evaluate perplexity of sent:  unexampled kindness to my poor sister. Ever since I have known
# Unrecognized Token ['irrevocably']
# Cound not evaluate perplexity of sent:  certain that, had you been absolutely, irrevocably decided
# Unrecognized Token ['frankly']
# Cound not evaluate perplexity of sent:  frankly and openly.”
# Unrecognized Token ['devoid']
# Cound not evaluate perplexity of sent:  “I can easily believe it. You thought me then devoid of every
# Unrecognized Token ['forgiven']
# Cound not evaluate perplexity of sent:  sister’s sentiments. He has heartily forgiven me now.”
# Unrecognized Token ['unacknowledged']
# Cound not evaluate perplexity of sent:  The acknowledged lovers talked and laughed, the unacknowledged
# Unrecognized Token ['springs']
# Cound not evaluate perplexity of sent:  what becomes of the moral, if our comfort springs from a breach
# Unrecognized Token ['etc']
# Cound not evaluate perplexity of sent:  “Yours sincerely, etc.”
# Unrecognized Token ['mrs']
# Cound not evaluate perplexity of sent:  delighted pride she afterwards visited Mrs. Bingley, and talked
# Unrecognized Token ['darling']
# Cound not evaluate perplexity of sent:  The darling wish of his sisters was then gratified; he bought an
# Unrecognized Token ['insipid']
# Cound not evaluate perplexity of sent:  management, less irritable, less ignorant, and less insipid. From
# Unrecognized Token ['abusive']
# Cound not evaluate perplexity of sent:  arrangement, she sent him language so very abusive, especially of
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  1.E.8.
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  1.B. "Project Gutenberg" is a registered trademark. It may only be
# Unrecognized Token ['unprotected']
# Cound not evaluate perplexity of sent:  States. If an individual work is unprotected by copyright law in the
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  1.E.2. If an individual Project Gutenberg-tm electronic work is
# Unrecognized Token ['files']
# Cound not evaluate perplexity of sent:  License terms from this work, or any files containing a part of this
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  full Project Gutenberg-tm License as specified in paragraph 1.E.1.
# Unrecognized Token ['mail']
# Cound not evaluate perplexity of sent:  you in writing (or by e-mail) within 30 days of receipt that s/he
# Unrecognized Token ['1']
# Cound not evaluate perplexity of sent:  * You provide, in accordance with paragraph 1.F.3, a full refund of
# Unrecognized Token ['incomplete']
# Cound not evaluate perplexity of sent:  contain "Defects," such as, but not limited to, incomplete, inaccurate
# Unrecognized Token ['merchantability']
# Cound not evaluate perplexity of sent:  LIMITED TO WARRANTIES OF MERCHANTABILITY OR FITNESS FOR ANY PURPOSE.
# Unrecognized Token ['exists']
# Cound not evaluate perplexity of sent:  exists because of the efforts of hundreds of volunteers and donations
# Unrecognized Token ['locations']
# Cound not evaluate perplexity of sent:  with these requirements. We do not solicit donations in locations
# Unrecognized Token ['statements']
# Cound not evaluate perplexity of sent:  any statements concerning tax treatment of donations received from
# Average LPP of bigram model over 9113 samples: 4.923907297882874, (std = 1.1000680075589357)

# %% [markdown]
# **The average LLP  over all parts is: 4.923**

# %% [markdown]
# ## Evaluate perplexity for the first ngram model

# %% [markdown]
# **I would expect that the log perplexity found before (second Kfold model) be higher than the log perplexity in the following evaluation (first ngram model). Because in the Kfold model, the test set is truly unseen data, therefore the perplexity of the model should be higher than in the first ngram model, where the test set was generated from the train set, and the likelyhood of each sentence is higher.**

# %%
ngram_sampled_sentences = []
for _ in range(1000):
  prompt = ['<s>']
  sentence = (" ".join(prompt + sample_from_model(model_3gram, prompt=prompt)))
  ngram_sampled_sentences.append(sentence)

# %%
ls_sampled = []
for sent in ngram_sampled_sentences:
  try:
    lpp = logperplexity(sent, model_3gram)
    if lpp > 0:
        ls_sampled += [lpp]
  except:
    print("Cound not evaluate perplexity of sent: ", sent)
print(f"Average LPP of bigram model over {len(ls_sampled)} samples: {np.mean(ls_sampled)}, (std = {np.std(ls_sampled)})")
# Out:
# Average LPP of bigram model over 1000 samples: 1.8078244421510534, (std = 0.4827903389516591)

# %% [markdown]
# **The average LLP  over all parts is: 1.808**.
#
# **As expected, the LLP of the first ngram model is lower than the LLP of the Kfold model**

# %% [markdown]
# ### 2. Entropy

# %% [markdown]
# #### 2.1 Estimating Entropy.
# Suppose that you observe a sequence of words (or letters) $x^n \in \Xcal^n$. Assume that $x^n$ represents a sample of identically and independently distributed (IID) RVs $X^n = (X_1,\ldots,X_n)$. Namely, all $X_i$s are sampled from the same distribution and $X_i$ is sampled independently form other $X_j$ for $j\neq i$. The PMF of $X_1$ obeys the law of large numbers (e.g. it has a finite variance). Define
# $$
# H_n(x^n) :=  \sum_{x\in \Xcal} \frac{N(x|x^n)}{n} \log \frac{N(x|x^n)}{n},
# $$
# where $N(x|x^n)$ denotes the number of occurances of $x$ in the sequence $x^n$ ( $N(x|x^n) = \sum_{i=1}^n \mathbf 1\{x=x_i\}$).
#
# Show that
# $$
# \lim_{n\to \infty} H_n(x^n)/n \to H(P_X)\quad \text{(in probability)},
# $$
# so that $H_n(x^n)/n$ is a consistent estimator of $H(P_X)$ (https://en.wikipedia.org/wiki/Consistent_estimator).
#
# Hint: use the law of large numbers, and the continuous mapping theorem (https://en.wikipedia.org/wiki/Continuous_mapping_theorem).

# %% [markdown]
# **2.1 ANSWER:**

# %% [markdown]
# Given the definition: $H_n(x^n) :=  -\sum_{x\in \Xcal} \frac{N(x|x^n)}{n} \log \frac{N(x|x^n)}{n}$ and given that $N(x|x^n)$ denotes the number of occurances of $x$ in the sequence $x^n$.
#
# Using the law of large numbers, we can state that as the sample size grows, its mean gets closer to the average of the whole population. Therefore, for ${n\to \infty}$, $x^n \to X^n$.
#
# Using the continuous mapping theorem, if $x_n \to X_n$ then $f(x_n) \to f(X_n)$. Therefore, we can say that: $\frac{N(x|x^n)}{n} \to \frac{N(x|X^n)}{n}$, which is similar to take the probability: $P_{X}(x)$ for ${n\to \infty}$.
#
# Thus placing it in the definition gives: $\lim_{n\to \infty} H_n(x^n) \to -\sum_{x\in \Xcal} P_{X}(x) \log P_{X}(x).$
#
# Also, the Shannon information associated with $P_X$ is: $-\sum_{x\in \Xcal} P_{X}(x) \log P_{X}(x)= H(P_X)$.
#
# By placing it in the previous equation we get: $\lim_{n\to \infty} H_n(x^n) \to H(P_X)$.

# %% [markdown]
# #### 2.2 Equivalent representations of conditional entropy
# (the porpuse of this question is to get you familiar with the probability notation).
#
# Let $X,Y$ be a pair of RVs with a joint mpf $P_{XY}$ such that $P_Y(y) > 0$ for all $y \in \Ycal$. Define:
# $$
# H(X|Y) :=  -\sum_{x \in \Xcal, y \in \Ycal} P_{XY}(x,y) \log_2 P_{X|Y}(x|y).
# $$
#
# Argue that:
# 1. $H(X|Y) = -\sum_{y \in \Ycal} P_Y(y) \sum_{x \in \Xcal} P_{X|Y}(x|y) \log \left(P_{X|Y}(x|y)\right)$
# 2. $H(X|Y) = \ex[H(X|Y=Y_1)]$ where $Y_1 \in \Ycal$ is a RV with pmf $P_Y$
# 3. $H(X|Y) = \ex\left[ -\log\left( P_{X|Y}(X_1|Y_1) \right) \right]$ where $Y_1 \in \Ycal$ and $X_1 \in \Xcal$ are  RVs with pmf $P_{XY}$
#
# Hint for 2 and 3: recall that for a function $f : \Xcal \to \reals$ and a RV $X \in \Xcal$ we define:
# $$
# \ex \left[f(X) \right] := \sum_{x \in \Xcal} P_X(x) f(x)
# $$

# %% [markdown]
# **2.2 ANSWER:**

# %% [markdown]
# 1.
# By definition, we are given that: $H(X|Y) :=  -\sum_{x \in \Xcal, y \in \Ycal} P_{XY}(x,y) \log_2 P_{X|Y}(x|y).$
#
# We knows from conditional probability that: $P_{X|Y}(x|y)=P_{XY}(x,y)/P_Y(y)$
#
# We can simplify that to: $P_{XY}(x,y)=P_Y(y)*P_{X|Y}(x|y)$
#
# Therefore, we can place the right hand side over the given first equation,
#
# and get: $H(X|Y) = -\sum_{x \in \Xcal, y \in \Ycal} P_Y(y)*P_{X|Y}(x|y) \log \left(P_{X|Y}(x|y)\right)$
#
# and by seperating the sums, we can simplify that to:
#
# $H(X|Y) = -\sum_{y \in \Ycal} P_Y(y) \sum_{x \in \Xcal} P_{X|Y}(x|y) \log \left(P_{X|Y}(x|y)\right)$

# %% [markdown]
# 2.
# We Knows from conditional probability that: $H(X|Y) :=  \sum_{y \in \Ycal} P_{Y}(y) H(X|Y=y).$
#
# We also knows from the hint that: $\ex \left[f(X) \right] := \sum_{x \in \Xcal} P_X(x) f(x)$
#
# Specifically in our case: $\ex(H(X|Y=y)) := \sum_{y \in \Ycal} P_{Y}(y)H(X|Y=y)$
#
# Therefore, we can place it in the right hand side of first equation, and get:
#
# $H(X|Y) :=  \ex(H(X|Y=Y_1)]$ where $Y_1 \in \Ycal$ is a RV with pmf $P_Y$

# %% [markdown]
# 3.
# By definition, we are given that: $H(X|Y) :=  -\sum_{x \in \Xcal, y \in \Ycal} P_{XY}(x,y) \log P_{X|Y}(x|y).$
#
# We also knows from the hint that: $\ex \left[f(X) \right] := \sum_{x \in \Xcal} P_X(x) f(x)$
#
# Specifically in our case: $\ex \left[-\log_2 P_{X|Y}(x|y) \right] := -\sum_{x \in \Xcal, y \in \Ycal} P_{XY}(x,y) \log_2 P_{X|Y}(x|y)$
#
# Therefore, we can place the left hand side over the given first equation, and get:
#
# $H(X|Y) = \ex\left[ -\log\left( P_{X|Y}(X_1|Y_1) \right) \right]$ where $Y_1 \in \Ycal$ and $X_1 \in \Xcal$ are  RVs with pmf $P_{XY}$
